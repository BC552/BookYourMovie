# %%
class Movie:
    
    def __init__(self):
        self.user_details = []
    
    def show_tickets(self):
        count = 0
        print('       CINEMA   ')
        for i in range(enter_rows+1):
            for j in range(enter_seats+1): 
                if i ==0:
                    if j==0:
                        print('  ',end=' ')

                    elif j>9:
                        print(j,end=' ')

                    else:
                        print(j,end=' ')

                elif i > 9:
                    if j==0:
                        print(count+1,end=' ')
                        count += 1

                    elif j > 9:
                        print(' S',end=' ')
                    else:
                        print('S',end=' ')


                else:
                    if j==0:
                        print(count+1,end='  ')
                        count += 1

                    elif j > 9:
                        print(' S',end=' ')
                    else:
                        print('S',end=' ')
            print()
            
    def buy_tickets(self):
        count = 0
        ite = 0
        
        enter_select_row = int(input("\nWhich row you want to book "))

        enter_select_column = input("Which column you want to book ")

        column_split = enter_select_column.split(',')
        len_column_split = len(column_split)

    #     print(len_column_split)
    #     print(column_split)


        for i in range(enter_rows+1):
            for j in range(enter_seats+1):

                if i == enter_select_row:
                    if j <= 9:

                        if j == int(column_split[ite]):
                            print('B',end=' ')


                            if ite < len_column_split-1:
                                ite += 1

                            continue
                            
                    else:
                        if j == int(column_split[ite]):
                            print(' B',end=' ')


                            if ite < len_column_split-1:
                                ite += 1

                            continue


                if i ==0:
                    if j==0:
                        print('  ',end=' ')

                    elif j>9:
                        print(j,end=' ')

                    else:
                        print(j,end=' ')
                        
                elif i > 9:
                    if j==0:
                        print(count+1,end=' ')
                        count += 1

                    elif j > 9:
                        print(' S',end=' ')
                    else:
                        print('S',end=' ')      
                        
                else:
                    if j==0:
                        print(count+1,end='  ')
                        count += 1

                    elif j > 9:
                        print(' S',end=' ')
                        
                    else:
                        print('S',end=' ')
            print()

        while True:
            user_choose = int(input('Choose your option \n1.Yes \n2.No  '))
            
            if user_choose == 1:
                
                name = input('Enter user name ')
                gender = input('Enter user gender ')
                age = int(input('Enter user age '))
                phone_no = int(input('Enter user phone number '))
                user_dic = {'Name':name,'Gender':gender,'Age':age,'Phone_no':phone_no}

                self.user_details.append(user_dic)
                
                break

            else:
                break
                
    def show_statistics(self):
        
        enter_select_row = int(input("\nEnter your row "))

        enter_select_column = input("Enter your column ")

        column_split = enter_select_column.split(',')
        len_column_split = len(column_split)

        if enter_rows * enter_seats <= 60:       

            print('\nNumber of purchases ticket: ',len_column_split)
        #     print('Percentage: ',1.79 * len_column_split)
            print('Current Income: ',"$",10 * len_column_split)

            print('Total Income: ','$',enter_rows * enter_seats * 10)
            print('Total number of seats: ',enter_rows * enter_seats)

        elif enter_rows * enter_seats > 60:  

            if enter_select_row <= 4:
                print('\nNumber of purchases ticket: ',len_column_split)
    #     print('Percentage: ',1.79 * len_column_split)
                print('Current Income: ',"$",10 * len_column_split)
                print('Total Income: ','$',enter_rows * enter_seats * 10)
                print('Total number of seats: ',enter_rows * enter_seats)        

            else:
                print('\nNumber of purchases ticket: ',len_column_split)
    #     print('Percentage: ',1.79 * len_column_split)
                print('Current Income: ',"$",8 * len_column_split)
                print('Total Income: ','$',enter_rows * enter_seats * 10)
                print('Total number of seats: ',enter_rows * enter_seats)
        
        
        
    def show_user_details(self):
        
        print('User Details\n')
        for i in self.user_details:
            for j,k in i.items():
                print(j,'----> ',k)
                
               
    
enter_rows = int(input('Enter number of rows '))
enter_seats = int(input('Enter number of seats each rows '))

m = Movie()

while True:
    print("\n1. Show the seats ")
    print("2. Buy a Tickets ")
    print("3. Statistics ")
    print("4. Show booked Ticket User Info ")
    print("0. Exit ")

    n = int(input("\nSelect Your Option "))
    
    if n ==1:
        m.show_tickets()
        
    elif n ==2:
        m.buy_tickets()
        
    elif n ==3:
        m.show_statistics()
        
    elif n ==4:
        m.show_user_details()
        
    else:
        break
# Out:
# Enter number of rows 10
# Enter number of seats each rows 10
#
# 1. Show the seats
# 2. Buy a Tickets
# 3. Statistics
# 4. Show booked Ticket User Info
# 0. Exit
#
# Select Your Option 0
